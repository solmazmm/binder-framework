# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sbs

# %%
import pandas as pd

# %%
df1=pd.read_csv('Solmaz_Moradi_Day4.csv')

# %%
df1.dropna()
# Out:
#    Neighborhood Tabulation Area (NTA) (2020)       Total Savings Job created
# 1                                     BK0101  10367.961794871795        16.0
# 2                                     BK0102  12599.753333333334        15.0
# 3                                     BK0103   19150.92285714286         0.0
# 4                                     BK0104  21158.253076923076       187.0
# 5                                     BK0201  15102.036363636364         0.0
# ..                                       ...                 ...         ...
# 68                                    QN1305          166379.352         0.0
# 69                                    QN1306          21160.5052         0.0
# 70                                    SI0106  6338.2528571428575        10.0
# 71                                    SI0107  113610.15999999999       300.0
# 72                                    SI0204   605464.8391666667         0.0
#
# [72 rows x 3 columns]

# %%
sbs.scatterplot(data=df1, x='Job created', y='Total Savings')
# Out:
# <AxesSubplot:xlabel='Job created', ylabel='Total Savings'>

# %%
sbs.scatterplot(data=df1, x='Job created', y='Total Savings')
plt.yscale('log')

# %%
sbs.histplot(
    df1,
    x="Job created",
)
# Out:
# <AxesSubplot:xlabel='Job created', ylabel='Count'>
